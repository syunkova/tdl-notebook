# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoViotti/tdl-notebook/blob/colab/tdl_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Globals

# %%
LOCAL = False

# %% [markdown]
# ## Install opensoundscape in this CoLab environment

# %%
if not LOCAL:
    # !pip install -q opensoundscape==0.9.1

# %% [markdown]
# ## Import libraries and set-up global configurations

# %%
if not LOCAL:
    from google.colab import drive
import os

from opensoundscape.spectrogram import Spectrogram
from opensoundscape.audio import Audio
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = [12,5]

# %% [markdown]
# ## Load data

# %%
if not LOCAL:
    mount = '/content/drive'
    drive.mount(mount)
else:
    folder_data = str(input(f"Enter audio data path:").strip())

# %%
if not LOCAL:
    folder_scripts = os.path.join(mount, 'My Drive/my-tdl-folder/scripts')
    os.chdir(folder_scripts)

    folder_data = os.path.join(mount, 'My Drive/my-tdl-folder/clips/subdir-if-exists')

# %% [markdown]
# ## Import custom modules

# %%
from annotation import *
from utils import *

# %% [markdown]
# ## Annotation

# %%
annotate(folder_data,
         valid_annotations = [1,0,'u'],
         scores_filename = '_scores.csv',
         path_column = 'clip_name')
